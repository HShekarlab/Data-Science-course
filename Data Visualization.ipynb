# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Tips = sns.load_dataset("tips")

# %%
Tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
Tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
Tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
Tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.countplot(x= "sex", data= Tips, color= "g", width= 0.6)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x= "day", data= Tips)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x= "time", data= Tips, color= "y")
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(x= "smoker", data= Tips)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x= "sex", data= Tips, hue= "day")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x= "sex", data= Tips, hue= "time")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x= "sex", data= Tips, hue= "smoker")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x= "smoker", data= Tips, hue= "time")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x= "day", data= Tips, hue= "time")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(x= "time", data= Tips, hue= "day")
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
x = Tips["total_bill"]

# %%
sns.displot(x)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(x, kde= True)
# Out:
# C:\Users\H_PC\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x= Tips["total_bill"], y= Tips["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x= "day", y= "total_bill", data= Tips, palette='rainbow')
# Out:
# C:\Users\H_PC\AppData\Local\Temp\ipykernel_1928\3024472436.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x= "day", y= "total_bill", data= Tips, palette='rainbow')

# %%
sns.boxplot(x= "day", y= "total_bill", data= Tips, palette='coolwarm')

# %%
sns.boxplot(x= "time", y= "total_bill", data= Tips, palette='rainbow')

# %%
sns.pairplot(Tips)

# %%
sns.pairplot(Tips, hue= "sex", palette='coolwarm')

# %%
sns.pairplot(Tips, hue= "day", palette='coolwarm')

# %%
sns.pairplot(Tips, hue= "time", palette='coolwarm')

# %%
sns.jointplot(x= "total_bill", y= "tip", data= Tips, kind= "scatter")

# %%
sns.jointplot(x= "total_bill", y= "tip", data= Tips, kind= "hist")

# %%
sns.jointplot(x= "total_bill", y= "tip", data= Tips, kind= "hex")

# %%
sns.jointplot(x= "total_bill", y= "tip", data= Tips, kind= "kde")

# %%
sns.jointplot(x= "total_bill", y= "tip", data= Tips, kind= "reg")

# %%
sns.jointplot(x= "total_bill", y= "tip", data= Tips, kind= "resid")

# %%
sns.jointplot(x= "total_bill", y= "size", data= Tips, kind= "scatter")

# %%
sns.jointplot(x= "tip", y= "size", data= Tips, kind= "scatter")

# %%
plt.subplot(1, 2, 1)
sns.countplot(x= "sex", data= Tips, color= "g")

plt.subplot(1, 2, 2)
sns.countplot(x= "day", data= Tips, color= "y")

# %%
plt.subplot(2, 2, 1)
sns.countplot(x= "sex", data= Tips, color= "b")

plt.subplot(2, 2, 2)
sns.countplot(x= "day", data= Tips, color= "g")

plt.subplot(2, 2, 3)
sns.countplot(x= "time", data= Tips, color= "m")

plt.subplot(2, 2, 4)
sns.countplot(x= "smoker", data= Tips, color= "r")
